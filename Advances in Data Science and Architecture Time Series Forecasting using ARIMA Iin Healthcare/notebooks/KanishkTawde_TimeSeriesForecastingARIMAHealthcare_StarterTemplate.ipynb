# %% [markdown]
# Name: Kanishk Tawde, NUID: 002293857, Advances in Data Science and Architecture

# %% [markdown]
# # Title: Time Series Forecasting using ARIMA in Healthcare - Starter Template

# %% [markdown]
# ### Student Template – ARIMA Forecasting of Daily ED Visits
#
# This notebook is a **starter template** for you to practice the full ARIMA workflow.
#
# Where you see `TODO`, you should:
#
# - Write your own code
# - Reuse ideas from the full walkthrough notebook
# - Experiment with different ARIMA parameters

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error

sns.set(style="whitegrid")
plt.rcParams["figure.dpi"] = 120

# %% [markdown]
# ### Load Data

# %%
# TODO 1: Load the ED dataset from data/daily_ed_visits.csv
# Hint: use pd.read_csv with parse_dates for the date column.

df = ...
df = ...
df.head()

# %% [markdown]
# ### Plot Raw Series

# %%
# TODO 2: Plot the raw time series of daily visits.

...

# %% [markdown]
# ### Rolling Mean/Std + ADF

# %%
# TODO 3: Compute and plot rolling mean/std.
# TODO 4: Run the ADF test and interpret the result.

...

# %% [markdown]
# ### Differencing + ADF Again

# %%
# TODO 5: Create a 'visits_diff' column with first-order differencing.
# TODO 6: Plot the differenced series and run ADF again.

...

# %% [markdown]
# ### ACF/PACF

# %%
# TODO 7: Plot ACF and PACF of the differenced series.

...

# %% [markdown]
# ### Train-Test Split

# %%
# TODO 8: Split the series into train and test sets chronologically.

...

# %% [markdown]
# ### Fit ARIMA

# %%
# TODO 9: Fit at least one ARIMA(p,d,q) model.
# Suggestion: start with ARIMA(1,1,1) and then try at least one alternative.

order = (1, 1, 1)
...

# %% [markdown]
# ### Forecast & Plot

# %%
# TODO 10: Forecast len(test) steps ahead and plot:
# - Train
# - Actual test
# - Forecast + confidence intervals

...

# %% [markdown]
# ### Evaluate & Interpret

# %%
# TODO 11: Compute MAE and RMSE and print them.
# Then, in a markdown cell, interpret:
# - Are the errors acceptable for operations?
# - Would you trust this model for staffing decisions?

...
